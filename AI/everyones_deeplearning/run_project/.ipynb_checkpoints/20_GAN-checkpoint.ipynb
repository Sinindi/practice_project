# %%
#-*- coding: utf-8 -*-

from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

#이미지가 저장될 폴더가 없다면 만듭니다.
import os
if not os.path.exists("./gan_images"):
    os.makedirs("./gan_images")

np.random.seed(3)
tf.random.set_seed(3)

#생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))

#판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False

#생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(100,))
dis_output = discriminator(generator(ginput))
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()

#신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):

  # MNIST 데이터 불러오기

  (X_train, _), (_, _) = mnist.load_data()  # 앞서 불러온 적 있는 MNIST를 다시 이용합니다. 단, 테스트과정은 필요없고 이미지만 사용할 것이기 때문에 X_train만 불러왔습니다.
  X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
  X_train = (X_train - 127.5) / 127.5  # 픽셀값은 0에서 255사이의 값입니다. 이전에 255로 나누어 줄때는 이를 0~1사이의 값으로 바꾸었던 것인데, 여기서는 127.5를 빼준 뒤 127.5로 나누어 줌으로 인해 -1에서 1사이의 값으로 바뀌게 됩니다.
  #X_train.shape, Y_train.shape, X_test.shape, Y_test.shape

  true = np.ones((batch_size, 1))
  fake = np.zeros((batch_size, 1))

  for i in range(epoch):
          # 실제 데이터를 판별자에 입력하는 부분입니다.
          idx = np.random.randint(0, X_train.shape[0], batch_size)
          imgs = X_train[idx]
          d_loss_real = discriminator.train_on_batch(imgs, true)

          #가상 이미지를 판별자에 입력하는 부분입니다.
          noise = np.random.normal(0, 1, (batch_size, 100))
          gen_imgs = generator.predict(noise)
          d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

          #판별자와 생성자의 오차를 계산합니다.
          d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
          g_loss = gan.train_on_batch(noise, true)

          print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # 이부분은 중간 과정을 이미지로 저장해 주는 부분입니다. 본 장의 주요 내용과 관련이 없어
        # 소스코드만 첨부합니다. 만들어진 이미지들은 gan_images 폴더에 저장됩니다.
          if i % saving_interval == 0:
              #r, c = 5, 5
              noise = np.random.normal(0, 1, (25, 100))
              gen_imgs = generator.predict(noise)

              # Rescale images 0 - 1
              gen_imgs = 0.5 * gen_imgs + 0.5

              fig, axs = plt.subplots(5, 5)
              count = 0
              for j in range(5):
                  for k in range(5):
                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                      axs[j, k].axis('off')
                      count += 1
              fig.savefig("gan_images/gan_mnist_%d.png" % i)

gan_train(4001, 32, 200)  #4000번 반복되고(+1을 해 주는 것에 주의), 배치 사이즈는 32,  200번 마다 결과가 저장되게 하였습니다.
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100)]             0
#
#  sequential (Sequential)     (None, 28, 28, 1)         865281
#
#  sequential_1 (Sequential)   (None, 1)                 212865
#
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________
# epoch:0  d_loss:0.7053  g_loss:0.6912
# epoch:1  d_loss:0.4624  g_loss:0.3281
# epoch:2  d_loss:0.5688  g_loss:0.1024
# epoch:3  d_loss:0.6579  g_loss:0.0836
# epoch:4  d_loss:0.5758  g_loss:0.1645
# epoch:5  d_loss:0.5085  g_loss:0.4191
# epoch:6  d_loss:0.4878  g_loss:0.6920
# epoch:7  d_loss:0.5097  g_loss:0.8625
# epoch:8  d_loss:0.4979  g_loss:0.8857
# epoch:9  d_loss:0.4887  g_loss:0.8594
# epoch:10  d_loss:0.4218  g_loss:0.7719
# epoch:11  d_loss:0.4452  g_loss:0.7958
# epoch:12  d_loss:0.4910  g_loss:0.8481
# epoch:13  d_loss:0.4878  g_loss:0.8962
# epoch:14  d_loss:0.5816  g_loss:0.9638
# epoch:15  d_loss:0.4866  g_loss:1.0706
# epoch:16  d_loss:0.4092  g_loss:1.0656
# epoch:17  d_loss:0.6200  g_loss:0.8033
# epoch:18  d_loss:0.5603  g_loss:0.6687
# epoch:19  d_loss:0.4593  g_loss:0.7125
# epoch:20  d_loss:0.4281  g_loss:0.7566
# epoch:21  d_loss:0.4924  g_loss:0.8042
# epoch:22  d_loss:0.5018  g_loss:0.6601
# epoch:23  d_loss:0.4478  g_loss:0.6208
# epoch:24  d_loss:0.4388  g_loss:0.6771
# epoch:25  d_loss:0.4623  g_loss:0.7014
# epoch:26  d_loss:0.4952  g_loss:0.6942
# epoch:27  d_loss:0.4551  g_loss:0.6000
# epoch:28  d_loss:0.4717  g_loss:0.5312
# epoch:29  d_loss:0.5080  g_loss:0.5969
# epoch:30  d_loss:0.4392  g_loss:0.6609
# epoch:31  d_loss:0.4508  g_loss:0.6885
# epoch:32  d_loss:0.4115  g_loss:0.5424
# epoch:33  d_loss:0.3935  g_loss:0.6967
# epoch:34  d_loss:0.3117  g_loss:0.7216
# epoch:35  d_loss:0.3736  g_loss:0.8134
# epoch:36  d_loss:0.3918  g_loss:0.6950
# epoch:37  d_loss:0.3264  g_loss:0.7873
# epoch:38  d_loss:0.3128  g_loss:1.0290
# epoch:39  d_loss:0.2270  g_loss:1.3531
# epoch:40  d_loss:0.3010  g_loss:1.3786
# epoch:41  d_loss:0.4096  g_loss:1.1869
# epoch:42  d_loss:0.3809  g_loss:0.9998
# epoch:43  d_loss:0.2173  g_loss:1.3134
# epoch:44  d_loss:0.1926  g_loss:1.5054
# epoch:45  d_loss:0.2148  g_loss:1.9844
# epoch:46  d_loss:0.4664  g_loss:1.2655
# epoch:47  d_loss:0.4463  g_loss:0.9898
# epoch:48  d_loss:0.3044  g_loss:1.9182
# epoch:49  d_loss:0.2852  g_loss:2.7101
# epoch:50  d_loss:0.2062  g_loss:2.3467
# epoch:51  d_loss:0.1263  g_loss:2.0237
# epoch:52  d_loss:0.1186  g_loss:1.9881
# epoch:53  d_loss:0.1662  g_loss:1.8982
# epoch:54  d_loss:0.1549  g_loss:2.8449
# epoch:55  d_loss:0.1632  g_loss:3.5347
# epoch:56  d_loss:0.4166  g_loss:2.0413
# epoch:57  d_loss:0.5653  g_loss:1.7603
# epoch:58  d_loss:0.6387  g_loss:2.4995
# epoch:59  d_loss:0.6030  g_loss:2.5009
# epoch:60  d_loss:0.8083  g_loss:2.5205
# epoch:61  d_loss:0.6918  g_loss:2.3967
# epoch:62  d_loss:0.6606  g_loss:2.5947
# epoch:63  d_loss:0.3055  g_loss:3.1958
# epoch:64  d_loss:0.4458  g_loss:3.2081
# epoch:65  d_loss:0.4847  g_loss:3.1001
# epoch:66  d_loss:0.4755  g_loss:2.4468
# epoch:67  d_loss:0.4691  g_loss:2.5496
# epoch:68  d_loss:0.2175  g_loss:3.4838
# epoch:69  d_loss:0.5948  g_loss:2.3535
# epoch:70  d_loss:0.8300  g_loss:1.3879
# epoch:71  d_loss:0.5408  g_loss:1.3172
# epoch:72  d_loss:0.7070  g_loss:1.6361
# epoch:73  d_loss:0.5331  g_loss:1.7464
# epoch:74  d_loss:0.7939  g_loss:1.1418
# epoch:75  d_loss:0.8193  g_loss:1.1452
# epoch:76  d_loss:0.6553  g_loss:1.2372
# epoch:77  d_loss:0.4589  g_loss:2.2511
# epoch:78  d_loss:0.4095  g_loss:2.8209
# epoch:79  d_loss:0.3059  g_loss:3.3330
# epoch:80  d_loss:0.2765  g_loss:3.0540
# epoch:81  d_loss:0.3369  g_loss:2.9631
# epoch:82  d_loss:0.3355  g_loss:3.0886
# epoch:83  d_loss:0.2275  g_loss:4.0905
# epoch:84  d_loss:0.3818  g_loss:4.2619
# epoch:85  d_loss:1.0373  g_loss:3.2870
# epoch:86  d_loss:0.6348  g_loss:4.1551
# epoch:87  d_loss:0.8427  g_loss:3.5080
# epoch:88  d_loss:1.0351  g_loss:2.8124
# epoch:89  d_loss:1.0380  g_loss:2.0520
# epoch:90  d_loss:0.7822  g_loss:2.4776
# epoch:91  d_loss:0.6477  g_loss:2.7219
# epoch:92  d_loss:0.7629  g_loss:2.1160
# epoch:93  d_loss:0.7188  g_loss:1.7170
# epoch:94  d_loss:0.5005  g_loss:1.3829
# epoch:95  d_loss:0.4796  g_loss:1.3719
# epoch:96  d_loss:0.4749  g_loss:1.3789
# epoch:97  d_loss:0.4105  g_loss:1.5514
# epoch:98  d_loss:0.4030  g_loss:1.3824
# epoch:99  d_loss:0.5554  g_loss:1.5121
# epoch:100  d_loss:0.4504  g_loss:1.2651
# epoch:101  d_loss:0.3541  g_loss:1.0673
# epoch:102  d_loss:0.3601  g_loss:1.0913
# epoch:103  d_loss:0.4874  g_loss:1.2171
# epoch:104  d_loss:0.3422  g_loss:0.9595
# epoch:105  d_loss:0.5198  g_loss:0.9778
# epoch:106  d_loss:0.5141  g_loss:0.9832
# epoch:107  d_loss:0.4742  g_loss:1.0600
# epoch:108  d_loss:0.4879  g_loss:1.0218
# epoch:109  d_loss:0.4536  g_loss:0.8726
# epoch:110  d_loss:0.4393  g_loss:1.1432
# epoch:111  d_loss:0.4423  g_loss:0.8222
# epoch:112  d_loss:0.5759  g_loss:0.9540
# epoch:113  d_loss:0.5591  g_loss:0.8640
# epoch:114  d_loss:0.7127  g_loss:0.7319
# epoch:115  d_loss:0.6611  g_loss:0.6989
# epoch:116  d_loss:0.7088  g_loss:0.7753
# epoch:117  d_loss:0.6069  g_loss:1.0076
# epoch:118  d_loss:0.6979  g_loss:0.7914
# epoch:119  d_loss:0.5827  g_loss:0.7838
# epoch:120  d_loss:0.7278  g_loss:0.7832
# epoch:121  d_loss:0.7378  g_loss:0.8380
# epoch:122  d_loss:0.8432  g_loss:0.8787
# epoch:123  d_loss:0.7910  g_loss:0.8676
# epoch:124  d_loss:0.6218  g_loss:1.1086
# epoch:125  d_loss:0.7428  g_loss:1.0487
# epoch:126  d_loss:0.6384  g_loss:1.0277
# epoch:127  d_loss:0.4822  g_loss:1.5149
# epoch:128  d_loss:0.4752  g_loss:1.5438
# epoch:129  d_loss:0.4098  g_loss:1.9080
# epoch:130  d_loss:0.4043  g_loss:1.8801
# epoch:131  d_loss:0.3588  g_loss:2.1289
# epoch:132  d_loss:0.3612  g_loss:1.8283
# epoch:133  d_loss:0.2874  g_loss:2.4598
# epoch:134  d_loss:0.3059  g_loss:2.5903
# epoch:135  d_loss:0.2785  g_loss:3.2177
# epoch:136  d_loss:0.4458  g_loss:2.8195
# epoch:137  d_loss:0.3962  g_loss:2.5453
# epoch:138  d_loss:0.4143  g_loss:2.5138
# epoch:139  d_loss:0.4723  g_loss:2.6925
# epoch:140  d_loss:0.5029  g_loss:2.6165
# epoch:141  d_loss:0.5529  g_loss:2.7774
# epoch:142  d_loss:0.9437  g_loss:1.7686
# epoch:143  d_loss:0.5941  g_loss:2.0007
# epoch:144  d_loss:0.7722  g_loss:1.7652
# epoch:145  d_loss:0.7100  g_loss:2.1521
# epoch:146  d_loss:0.7326  g_loss:2.3040
# epoch:147  d_loss:0.9657  g_loss:1.8688
# epoch:148  d_loss:0.8245  g_loss:1.9485
# epoch:149  d_loss:0.6431  g_loss:1.9321
# epoch:150  d_loss:0.6995  g_loss:1.5367
# epoch:151  d_loss:0.6043  g_loss:1.5205
# epoch:152  d_loss:0.6136  g_loss:1.4764
# epoch:153  d_loss:0.5202  g_loss:1.6486
# epoch:154  d_loss:0.4749  g_loss:1.6186
# epoch:155  d_loss:0.4979  g_loss:1.7764
# epoch:156  d_loss:0.4868  g_loss:1.7396
# epoch:157  d_loss:0.4986  g_loss:1.7505
# epoch:158  d_loss:0.4253  g_loss:1.7431
# epoch:159  d_loss:0.3846  g_loss:1.7908
# epoch:160  d_loss:0.3803  g_loss:1.7864
# epoch:161  d_loss:0.4376  g_loss:1.7410
# epoch:162  d_loss:0.4683  g_loss:1.4274
# epoch:163  d_loss:0.3402  g_loss:1.7091
# epoch:164  d_loss:0.3663  g_loss:1.7105
# epoch:165  d_loss:0.3043  g_loss:1.8286
# epoch:166  d_loss:0.3620  g_loss:1.9750
# epoch:167  d_loss:0.4018  g_loss:1.7937
# epoch:168  d_loss:0.3946  g_loss:1.8274
# epoch:169  d_loss:0.4409  g_loss:1.7808
# epoch:170  d_loss:0.3886  g_loss:1.6739
# epoch:171  d_loss:0.4148  g_loss:1.4031
# epoch:172  d_loss:0.4134  g_loss:1.4353
# epoch:173  d_loss:0.3348  g_loss:1.5045
# epoch:174  d_loss:0.4558  g_loss:1.5032
# epoch:175  d_loss:0.3930  g_loss:1.6602
# epoch:176  d_loss:0.5421  g_loss:1.5611
# epoch:177  d_loss:0.5159  g_loss:1.4942
# epoch:178  d_loss:0.3626  g_loss:1.3915
# epoch:179  d_loss:0.4469  g_loss:1.3805
# epoch:180  d_loss:0.4824  g_loss:1.0823
# epoch:181  d_loss:0.4419  g_loss:1.3297
# epoch:182  d_loss:0.5574  g_loss:1.1435
# epoch:183  d_loss:0.4853  g_loss:1.5029
# epoch:184  d_loss:0.4595  g_loss:1.2881
# epoch:185  d_loss:0.6721  g_loss:1.1755
# epoch:186  d_loss:0.6074  g_loss:1.1784
# epoch:187  d_loss:0.6613  g_loss:1.1715
# epoch:188  d_loss:0.8131  g_loss:1.0491
# epoch:189  d_loss:0.6278  g_loss:0.9497
# epoch:190  d_loss:0.5260  g_loss:1.0953
# epoch:191  d_loss:0.6766  g_loss:1.0951
# epoch:192  d_loss:0.6285  g_loss:1.2112
# epoch:193  d_loss:0.6735  g_loss:1.1139
# epoch:194  d_loss:0.6850  g_loss:1.0834
# epoch:195  d_loss:0.5964  g_loss:1.1088
# epoch:196  d_loss:0.5415  g_loss:1.0300
# epoch:197  d_loss:0.4875  g_loss:1.2421
# epoch:198  d_loss:0.4962  g_loss:1.4533
# epoch:199  d_loss:0.4584  g_loss:1.5874
# epoch:200  d_loss:0.5914  g_loss:1.5932
# epoch:201  d_loss:0.5130  g_loss:1.4034
# epoch:202  d_loss:0.5749  g_loss:1.3016
# epoch:203  d_loss:0.3612  g_loss:1.4768
# epoch:204  d_loss:0.4194  g_loss:1.5758
# epoch:205  d_loss:0.3709  g_loss:1.9030
# epoch:206  d_loss:0.3688  g_loss:2.1780
# epoch:207  d_loss:0.4029  g_loss:2.2070
# epoch:208  d_loss:0.4895  g_loss:2.0645
# epoch:209  d_loss:0.3422  g_loss:1.7081
# epoch:210  d_loss:0.4570  g_loss:1.6081
# epoch:211  d_loss:0.4059  g_loss:2.2061
# epoch:212  d_loss:0.3621  g_loss:2.0557
# epoch:213  d_loss:0.4863  g_loss:2.1765
# epoch:214  d_loss:0.4591  g_loss:1.7069
# epoch:215  d_loss:0.4606  g_loss:1.8524
# epoch:216  d_loss:0.5565  g_loss:1.9484
# epoch:217  d_loss:0.4183  g_loss:1.7616
# epoch:218  d_loss:0.3667  g_loss:2.0807
# epoch:219  d_loss:0.4347  g_loss:2.0354
# epoch:220  d_loss:0.4546  g_loss:1.9203
# epoch:221  d_loss:0.5267  g_loss:1.7789
# epoch:222  d_loss:0.4806  g_loss:1.6845
# epoch:223  d_loss:0.4003  g_loss:1.8183
# epoch:224  d_loss:0.5604  g_loss:1.5640
# epoch:225  d_loss:0.4148  g_loss:1.7963
# epoch:226  d_loss:0.4970  g_loss:1.4939
# epoch:227  d_loss:0.5600  g_loss:1.8026
# epoch:228  d_loss:0.5206  g_loss:1.6039
# epoch:229  d_loss:0.5247  g_loss:1.8814
# epoch:230  d_loss:0.5020  g_loss:1.7881
# epoch:231  d_loss:0.6575  g_loss:1.6815
# epoch:232  d_loss:0.5833  g_loss:1.8939
# epoch:233  d_loss:0.5955  g_loss:1.4727
# epoch:234  d_loss:0.6783  g_loss:1.3194
# epoch:235  d_loss:0.5447  g_loss:1.3960
# epoch:236  d_loss:0.5301  g_loss:1.2773
# epoch:237  d_loss:0.4365  g_loss:1.5946
# epoch:238  d_loss:0.4907  g_loss:1.6315
# epoch:239  d_loss:0.3990  g_loss:1.7848
# epoch:240  d_loss:0.5860  g_loss:1.4929
# epoch:241  d_loss:0.6035  g_loss:1.5629
# epoch:242  d_loss:0.5335  g_loss:1.6293
# epoch:243  d_loss:0.4983  g_loss:1.4193
# epoch:244  d_loss:0.5081  g_loss:1.4544
# epoch:245  d_loss:0.4183  g_loss:1.4607
# epoch:246  d_loss:0.5313  g_loss:1.5373
# epoch:247  d_loss:0.4046  g_loss:1.8866
# epoch:248  d_loss:0.4255  g_loss:1.6559
# epoch:249  d_loss:0.4614  g_loss:1.8091
# epoch:250  d_loss:0.4003  g_loss:1.7470
# epoch:251  d_loss:0.3431  g_loss:1.8331
# epoch:252  d_loss:0.3920  g_loss:1.3056
# epoch:253  d_loss:0.4188  g_loss:1.3007
# epoch:254  d_loss:0.5586  g_loss:1.5214
# epoch:255  d_loss:0.5086  g_loss:1.6973
# epoch:256  d_loss:0.4759  g_loss:1.7430
# epoch:257  d_loss:0.3339  g_loss:2.1072
# epoch:258  d_loss:0.4632  g_loss:1.8403
# epoch:259  d_loss:0.5727  g_loss:1.8775
# epoch:260  d_loss:0.4193  g_loss:1.5348
# epoch:261  d_loss:0.4073  g_loss:1.5340
# epoch:262  d_loss:0.4844  g_loss:1.6023
# epoch:263  d_loss:0.5019  g_loss:2.0261
# epoch:264  d_loss:0.4763  g_loss:2.1953
# epoch:265  d_loss:0.6185  g_loss:1.7417
# epoch:266  d_loss:0.2923  g_loss:2.2620
# epoch:267  d_loss:0.4837  g_loss:1.9691
# epoch:268  d_loss:0.5484  g_loss:1.5283
# epoch:269  d_loss:0.3832  g_loss:2.1867
# epoch:270  d_loss:0.4995  g_loss:1.7684
# epoch:271  d_loss:0.4473  g_loss:1.9520
# epoch:272  d_loss:0.3465  g_loss:2.3007
# epoch:273  d_loss:0.4138  g_loss:2.4815
# epoch:274  d_loss:0.5616  g_loss:2.0684
# epoch:275  d_loss:0.4728  g_loss:1.9491
# epoch:276  d_loss:0.4900  g_loss:2.1051
# epoch:277  d_loss:0.6159  g_loss:1.7433
# epoch:278  d_loss:0.3236  g_loss:1.9094
# epoch:279  d_loss:0.3943  g_loss:1.8425
# epoch:280  d_loss:0.4068  g_loss:1.7208
# epoch:281  d_loss:0.4352  g_loss:2.0153
# epoch:282  d_loss:0.3441  g_loss:2.2499
# epoch:283  d_loss:0.4209  g_loss:2.0692
# epoch:284  d_loss:0.5902  g_loss:1.5315
# epoch:285  d_loss:0.4780  g_loss:2.1598
# epoch:286  d_loss:0.4213  g_loss:1.9368
# epoch:287  d_loss:0.3976  g_loss:2.1261
# epoch:288  d_loss:0.5085  g_loss:2.2074
# epoch:289  d_loss:0.5456  g_loss:1.9537
# epoch:290  d_loss:0.5599  g_loss:1.7085
# epoch:291  d_loss:0.5229  g_loss:1.4061
# epoch:292  d_loss:0.5257  g_loss:1.3849
# epoch:293  d_loss:0.5171  g_loss:1.5981
# epoch:294  d_loss:0.5133  g_loss:1.5552
# epoch:295  d_loss:0.5599  g_loss:1.7491
# epoch:296  d_loss:0.4629  g_loss:1.9209
# epoch:297  d_loss:0.5099  g_loss:1.8135
# epoch:298  d_loss:0.6491  g_loss:1.3211
# epoch:299  d_loss:0.6758  g_loss:1.3251
# epoch:300  d_loss:0.6168  g_loss:1.6556
# epoch:301  d_loss:0.5748  g_loss:1.4297
# epoch:302  d_loss:0.4985  g_loss:1.6837
# epoch:303  d_loss:0.4768  g_loss:1.6786
# epoch:304  d_loss:0.5651  g_loss:1.4246
# epoch:305  d_loss:0.5319  g_loss:1.5294
# epoch:306  d_loss:0.4232  g_loss:1.6691
# epoch:307  d_loss:0.4297  g_loss:1.5991
# epoch:308  d_loss:0.3538  g_loss:1.7933
# epoch:309  d_loss:0.4306  g_loss:1.9013
# epoch:310  d_loss:0.5099  g_loss:1.8127
# epoch:311  d_loss:0.3684  g_loss:1.9507
# epoch:312  d_loss:0.4074  g_loss:1.6670
# epoch:313  d_loss:0.4022  g_loss:1.6077
# epoch:314  d_loss:0.3982  g_loss:1.8657
# epoch:315  d_loss:0.3454  g_loss:1.9037
# epoch:316  d_loss:0.3885  g_loss:1.8113
# epoch:317  d_loss:0.3277  g_loss:2.1623
# epoch:318  d_loss:0.4323  g_loss:1.9577
# epoch:319  d_loss:0.3597  g_loss:2.1514
# epoch:320  d_loss:0.3176  g_loss:2.6619
# epoch:321  d_loss:0.4840  g_loss:1.7473
# epoch:322  d_loss:0.3887  g_loss:1.8053
# epoch:323  d_loss:0.3549  g_loss:1.9733
# epoch:324  d_loss:0.3627  g_loss:1.8054
# epoch:325  d_loss:0.4294  g_loss:1.8956
# epoch:326  d_loss:0.5643  g_loss:1.7202
# epoch:327  d_loss:0.2998  g_loss:2.4845
# epoch:328  d_loss:0.3690  g_loss:2.5198
# epoch:329  d_loss:0.4184  g_loss:2.0290
# epoch:330  d_loss:0.4603  g_loss:1.9415
# epoch:331  d_loss:0.4072  g_loss:1.9018
# epoch:332  d_loss:0.5246  g_loss:1.7109
# epoch:333  d_loss:0.4284  g_loss:1.7415
# epoch:334  d_loss:0.5981  g_loss:1.3833
# epoch:335  d_loss:0.5058  g_loss:1.5431
# epoch:336  d_loss:0.4305  g_loss:1.9961
# epoch:337  d_loss:0.3914  g_loss:1.9318
# epoch:338  d_loss:0.6954  g_loss:1.8573
# epoch:339  d_loss:0.4959  g_loss:1.8420
# epoch:340  d_loss:0.4620  g_loss:1.8288
# epoch:341  d_loss:0.5495  g_loss:1.5831
# epoch:342  d_loss:0.5409  g_loss:1.6670
# epoch:343  d_loss:0.5373  g_loss:1.9438
# epoch:344  d_loss:0.4237  g_loss:1.8648
# epoch:345  d_loss:0.6047  g_loss:2.2926
# epoch:346  d_loss:0.6566  g_loss:1.8773
# epoch:347  d_loss:0.4084  g_loss:1.9323
# epoch:348  d_loss:0.4983  g_loss:2.1621
# epoch:349  d_loss:0.4505  g_loss:2.0302
# epoch:350  d_loss:0.4077  g_loss:2.0393
# epoch:351  d_loss:0.4171  g_loss:2.0527
# epoch:352  d_loss:0.3750  g_loss:1.9261
# epoch:353  d_loss:0.4436  g_loss:2.3993
# epoch:354  d_loss:0.6143  g_loss:1.7582
# epoch:355  d_loss:0.4168  g_loss:2.3214
# epoch:356  d_loss:0.4425  g_loss:2.5561
# epoch:357  d_loss:0.3603  g_loss:2.4214
# epoch:358  d_loss:0.4231  g_loss:2.7296
# epoch:359  d_loss:0.3036  g_loss:2.6583
# epoch:360  d_loss:0.3269  g_loss:2.3009
# epoch:361  d_loss:0.3183  g_loss:2.2181
# epoch:362  d_loss:0.2156  g_loss:2.7142
# epoch:363  d_loss:0.3245  g_loss:2.3108
# epoch:364  d_loss:0.2016  g_loss:3.2599
# epoch:365  d_loss:0.2917  g_loss:3.3941
# epoch:366  d_loss:0.4523  g_loss:2.2798
# epoch:367  d_loss:0.5428  g_loss:2.0622
# epoch:368  d_loss:0.3022  g_loss:2.4945
# epoch:369  d_loss:0.3221  g_loss:2.5851
# epoch:370  d_loss:0.4812  g_loss:2.6821
# epoch:371  d_loss:0.3196  g_loss:2.4898
# epoch:372  d_loss:0.3343  g_loss:2.5371
# epoch:373  d_loss:0.2383  g_loss:2.4715
# epoch:374  d_loss:0.3112  g_loss:2.5819
# epoch:375  d_loss:0.3609  g_loss:2.5577
# epoch:376  d_loss:0.3455  g_loss:1.9564
# epoch:377  d_loss:0.2802  g_loss:2.5232
# epoch:378  d_loss:0.3177  g_loss:2.6395
# epoch:379  d_loss:0.3796  g_loss:2.5023
# epoch:380  d_loss:0.3291  g_loss:2.5167
# epoch:381  d_loss:0.3114  g_loss:2.8604
# epoch:382  d_loss:0.3315  g_loss:2.0000
# epoch:383  d_loss:0.3919  g_loss:1.9333
# epoch:384  d_loss:0.3811  g_loss:1.8635
# epoch:385  d_loss:0.4460  g_loss:1.9059
# epoch:386  d_loss:0.3347  g_loss:2.3564
# epoch:387  d_loss:0.2656  g_loss:2.2762
# epoch:388  d_loss:0.4184  g_loss:2.3293
# epoch:389  d_loss:0.2569  g_loss:2.5467
# epoch:390  d_loss:0.5824  g_loss:1.8871
# epoch:391  d_loss:0.3285  g_loss:1.7731
# epoch:392  d_loss:0.4410  g_loss:1.7028
# epoch:393  d_loss:0.4051  g_loss:1.8920
# epoch:394  d_loss:0.3046  g_loss:1.9244
# epoch:395  d_loss:0.4047  g_loss:2.1905
# epoch:396  d_loss:0.4226  g_loss:2.0073
# epoch:397  d_loss:0.3316  g_loss:2.2350
# epoch:398  d_loss:0.4879  g_loss:1.8876
# epoch:399  d_loss:0.4737  g_loss:1.5669
# epoch:400  d_loss:0.4909  g_loss:1.8137
# epoch:401  d_loss:0.3272  g_loss:2.2890
# epoch:402  d_loss:0.3987  g_loss:2.5195
# epoch:403  d_loss:0.3320  g_loss:2.6766
# epoch:404  d_loss:0.3468  g_loss:2.1375
# epoch:405  d_loss:0.3860  g_loss:1.9705
# epoch:406  d_loss:0.2089  g_loss:2.0584
# epoch:407  d_loss:0.3692  g_loss:2.0055
# epoch:408  d_loss:0.3067  g_loss:2.1991
# epoch:409  d_loss:0.2749  g_loss:2.0349
# epoch:410  d_loss:0.2718  g_loss:2.4466
# epoch:411  d_loss:0.2756  g_loss:2.4507
# epoch:412  d_loss:0.3778  g_loss:1.9767
# epoch:413  d_loss:0.3239  g_loss:1.9970
# epoch:414  d_loss:0.3902  g_loss:2.3082
# epoch:415  d_loss:0.4040  g_loss:2.0198
# epoch:416  d_loss:0.3106  g_loss:2.4301
# epoch:417  d_loss:0.2815  g_loss:2.5706
# epoch:418  d_loss:0.3306  g_loss:2.7458
# epoch:419  d_loss:0.3701  g_loss:2.6479
# epoch:420  d_loss:0.2277  g_loss:2.3416
# epoch:421  d_loss:0.2788  g_loss:1.9522
# epoch:422  d_loss:0.3537  g_loss:2.2145
# epoch:423  d_loss:0.2479  g_loss:2.6559
# epoch:424  d_loss:0.3094  g_loss:2.3472
# epoch:425  d_loss:0.2630  g_loss:2.7016
# epoch:426  d_loss:0.2446  g_loss:3.0664
# epoch:427  d_loss:0.3405  g_loss:3.2686
# epoch:428  d_loss:0.3314  g_loss:3.2096
# epoch:429  d_loss:0.3139  g_loss:3.1093
# epoch:430  d_loss:0.5410  g_loss:2.5657
# epoch:431  d_loss:0.2770  g_loss:2.4521
# epoch:432  d_loss:0.4718  g_loss:1.9609
# epoch:433  d_loss:0.3291  g_loss:2.6168
# epoch:434  d_loss:0.3733  g_loss:2.2724
# epoch:435  d_loss:0.3584  g_loss:2.4681
# epoch:436  d_loss:0.2321  g_loss:2.3631
# epoch:437  d_loss:0.3430  g_loss:2.8919
# epoch:438  d_loss:0.4881  g_loss:1.9964
# epoch:439  d_loss:0.2771  g_loss:2.5538
# epoch:440  d_loss:0.3569  g_loss:2.5417
# epoch:441  d_loss:0.2523  g_loss:2.9648
# epoch:442  d_loss:0.3409  g_loss:2.3080
# epoch:443  d_loss:0.2923  g_loss:2.4965
# epoch:444  d_loss:0.3434  g_loss:2.1126
# epoch:445  d_loss:0.3657  g_loss:1.9578
# epoch:446  d_loss:0.3016  g_loss:2.1915
# epoch:447  d_loss:0.2975  g_loss:2.5955
# epoch:448  d_loss:0.3532  g_loss:2.5506
# epoch:449  d_loss:0.4264  g_loss:2.2906
# epoch:450  d_loss:0.3813  g_loss:2.3157
# epoch:451  d_loss:0.2815  g_loss:2.9333
# epoch:452  d_loss:0.4082  g_loss:2.6120
# epoch:453  d_loss:0.3224  g_loss:2.6587
# epoch:454  d_loss:0.3535  g_loss:2.5302
# epoch:455  d_loss:0.4796  g_loss:2.1659
# epoch:456  d_loss:0.4901  g_loss:1.5419
# epoch:457  d_loss:0.3750  g_loss:1.9288
# epoch:458  d_loss:0.3118  g_loss:2.1475
# epoch:459  d_loss:0.3039  g_loss:2.3228
# epoch:460  d_loss:0.2797  g_loss:2.5533
# epoch:461  d_loss:0.3238  g_loss:2.3709
# epoch:462  d_loss:0.2593  g_loss:2.2004
# epoch:463  d_loss:0.3225  g_loss:2.1753
# epoch:464  d_loss:0.2913  g_loss:2.2431
# epoch:465  d_loss:0.2409  g_loss:2.8207
# epoch:466  d_loss:0.2995  g_loss:2.5560
# epoch:467  d_loss:0.3613  g_loss:2.5982
# epoch:468  d_loss:0.2196  g_loss:2.0399
# epoch:469  d_loss:0.2715  g_loss:2.8192
# epoch:470  d_loss:0.2334  g_loss:3.0640
# epoch:471  d_loss:0.3691  g_loss:2.5988
# epoch:472  d_loss:0.2406  g_loss:2.3953
# epoch:473  d_loss:0.2674  g_loss:2.1013
# epoch:474  d_loss:0.3047  g_loss:2.4699
# epoch:475  d_loss:0.2618  g_loss:2.3423
# epoch:476  d_loss:0.2783  g_loss:2.5364
# epoch:477  d_loss:0.2766  g_loss:2.4193
# epoch:478  d_loss:0.2554  g_loss:2.7366
# epoch:479  d_loss:0.2198  g_loss:2.6428
# epoch:480  d_loss:0.2707  g_loss:2.3577
# epoch:481  d_loss:0.2563  g_loss:2.6305
# epoch:482  d_loss:0.3744  g_loss:1.9917
# epoch:483  d_loss:0.3130  g_loss:2.0957
# epoch:484  d_loss:0.2725  g_loss:1.9360
# epoch:485  d_loss:0.2431  g_loss:2.3183
# epoch:486  d_loss:0.3715  g_loss:1.7447
# epoch:487  d_loss:0.4061  g_loss:1.7587
# epoch:488  d_loss:0.4022  g_loss:1.9008
# epoch:489  d_loss:0.4095  g_loss:1.9070
# epoch:490  d_loss:0.3221  g_loss:2.2363
# epoch:491  d_loss:0.2354  g_loss:2.3930
# epoch:492  d_loss:0.3302  g_loss:1.9223
# epoch:493  d_loss:0.3202  g_loss:1.8412
# epoch:494  d_loss:0.2636  g_loss:2.1513
# epoch:495  d_loss:0.2721  g_loss:2.6339
# epoch:496  d_loss:0.2779  g_loss:2.8874
# epoch:497  d_loss:0.3614  g_loss:2.8583
# epoch:498  d_loss:0.3633  g_loss:1.9482
# epoch:499  d_loss:0.3437  g_loss:1.6932
# epoch:500  d_loss:0.2433  g_loss:2.0011
# epoch:501  d_loss:0.1646  g_loss:2.8834
# epoch:502  d_loss:0.2752  g_loss:3.1307
# epoch:503  d_loss:0.2704  g_loss:2.7397
# epoch:504  d_loss:0.2896  g_loss:2.0420
# epoch:505  d_loss:0.1470  g_loss:3.0544
# epoch:506  d_loss:0.1745  g_loss:2.6337
# epoch:507  d_loss:0.2068  g_loss:2.6130
# epoch:508  d_loss:0.1748  g_loss:3.2724
# epoch:509  d_loss:0.1740  g_loss:3.2952
# epoch:510  d_loss:0.2509  g_loss:2.3066
# epoch:511  d_loss:0.1342  g_loss:2.7900
# epoch:512  d_loss:0.1509  g_loss:2.9228
# epoch:513  d_loss:0.1877  g_loss:2.6625
# epoch:514  d_loss:0.1674  g_loss:2.7027
# epoch:515  d_loss:0.1808  g_loss:2.7348
# epoch:516  d_loss:0.1378  g_loss:2.2635
# epoch:517  d_loss:0.2125  g_loss:2.7144
# epoch:518  d_loss:0.1928  g_loss:3.9067
# epoch:519  d_loss:0.2736  g_loss:3.4504
# epoch:520  d_loss:0.1995  g_loss:3.5910
# epoch:521  d_loss:0.2883  g_loss:2.6744
# epoch:522  d_loss:0.3190  g_loss:2.2723
# epoch:523  d_loss:0.3055  g_loss:2.4725
# epoch:524  d_loss:0.1964  g_loss:3.3003
# epoch:525  d_loss:0.2507  g_loss:3.1270
# epoch:526  d_loss:0.1960  g_loss:3.4110
# epoch:527  d_loss:0.2466  g_loss:3.3823
# epoch:528  d_loss:0.3119  g_loss:2.1975
# epoch:529  d_loss:0.3003  g_loss:2.2172
# epoch:530  d_loss:0.2634  g_loss:2.2225
# epoch:531  d_loss:0.2090  g_loss:3.1085
# epoch:532  d_loss:0.1941  g_loss:3.5856
# epoch:533  d_loss:0.2157  g_loss:2.9077
# epoch:534  d_loss:0.2313  g_loss:2.9517
# epoch:535  d_loss:0.1569  g_loss:3.0087
# epoch:536  d_loss:0.2358  g_loss:2.8060
# epoch:537  d_loss:0.2128  g_loss:2.1332
# epoch:538  d_loss:0.2159  g_loss:2.7539
# epoch:539  d_loss:0.2742  g_loss:2.6033
# epoch:540  d_loss:0.2471  g_loss:2.4560
# epoch:541  d_loss:0.2223  g_loss:2.1757
# epoch:542  d_loss:0.3832  g_loss:2.1151
# epoch:543  d_loss:0.3790  g_loss:2.0023
# epoch:544  d_loss:0.3636  g_loss:2.0623
# epoch:545  d_loss:0.3508  g_loss:1.8860
# epoch:546  d_loss:0.2366  g_loss:2.2731
# epoch:547  d_loss:0.2164  g_loss:2.7520
# epoch:548  d_loss:0.2789  g_loss:2.5546
# epoch:549  d_loss:0.5679  g_loss:2.3996
# epoch:550  d_loss:0.3252  g_loss:2.1684
# epoch:551  d_loss:0.1324  g_loss:2.7401
# epoch:552  d_loss:0.4757  g_loss:2.7419
# epoch:553  d_loss:0.4857  g_loss:2.0273
# epoch:554  d_loss:0.2811  g_loss:1.9019
# epoch:555  d_loss:0.3774  g_loss:2.2822
# epoch:556  d_loss:0.1846  g_loss:3.2501
# epoch:557  d_loss:0.2238  g_loss:4.1705
# epoch:558  d_loss:0.3545  g_loss:3.3335
# epoch:559  d_loss:0.1920  g_loss:2.2570
# epoch:560  d_loss:0.2445  g_loss:2.3732
# epoch:561  d_loss:0.1683  g_loss:2.5366
# epoch:562  d_loss:0.1785  g_loss:2.9836
# epoch:563  d_loss:0.1403  g_loss:4.8555
# epoch:564  d_loss:0.3559  g_loss:3.4043
# epoch:565  d_loss:0.2223  g_loss:2.9771
# epoch:566  d_loss:0.0750  g_loss:3.1179
# epoch:567  d_loss:0.1950  g_loss:2.6146
# epoch:568  d_loss:0.1996  g_loss:2.3524
# epoch:569  d_loss:0.2419  g_loss:2.5472
# epoch:570  d_loss:0.2497  g_loss:2.4984
# epoch:571  d_loss:0.2493  g_loss:3.6074
# epoch:572  d_loss:0.1116  g_loss:3.0805
# epoch:573  d_loss:0.2765  g_loss:2.4252
# epoch:574  d_loss:0.1164  g_loss:2.0437
# epoch:575  d_loss:0.1310  g_loss:2.7127
# epoch:576  d_loss:0.2430  g_loss:3.6267
# epoch:577  d_loss:0.1595  g_loss:3.9132
# epoch:578  d_loss:0.2306  g_loss:4.8672
# epoch:579  d_loss:0.2003  g_loss:4.2821
# epoch:580  d_loss:0.1791  g_loss:2.9282
# epoch:581  d_loss:0.1151  g_loss:2.9643
# epoch:582  d_loss:0.4005  g_loss:3.0096
# epoch:583  d_loss:0.1557  g_loss:4.7946
# epoch:584  d_loss:0.2777  g_loss:4.0045
# epoch:585  d_loss:0.2663  g_loss:3.2010
# epoch:586  d_loss:0.2658  g_loss:2.5133
# epoch:587  d_loss:0.2160  g_loss:3.2189
# epoch:588  d_loss:0.3093  g_loss:3.1338
# epoch:589  d_loss:0.3790  g_loss:3.6955
# epoch:590  d_loss:0.5307  g_loss:2.6062
# epoch:591  d_loss:0.2985  g_loss:2.2565
# epoch:592  d_loss:0.2998  g_loss:2.5515
# epoch:593  d_loss:0.1192  g_loss:4.9577
# epoch:594  d_loss:0.1242  g_loss:4.5801
# epoch:595  d_loss:0.4218  g_loss:3.1033
# epoch:596  d_loss:0.2557  g_loss:2.3640
# epoch:597  d_loss:0.2717  g_loss:2.3008
# epoch:598  d_loss:0.2164  g_loss:2.2442
# epoch:599  d_loss:0.1912  g_loss:3.4156
# epoch:600  d_loss:0.2002  g_loss:3.7826
# epoch:601  d_loss:0.2264  g_loss:3.9080
# epoch:602  d_loss:0.3012  g_loss:3.2836
# epoch:603  d_loss:0.1996  g_loss:2.7286
# epoch:604  d_loss:0.2424  g_loss:2.2043
# epoch:605  d_loss:0.1756  g_loss:2.3685
# epoch:606  d_loss:0.1924  g_loss:2.1703
# epoch:607  d_loss:0.1908  g_loss:2.6135
# epoch:608  d_loss:0.2891  g_loss:2.9409
# epoch:609  d_loss:0.2472  g_loss:2.6953
# epoch:610  d_loss:0.3065  g_loss:2.1466
# epoch:611  d_loss:0.3096  g_loss:2.2648
# epoch:612  d_loss:0.2602  g_loss:2.2054
# epoch:613  d_loss:0.4537  g_loss:2.9274
# epoch:614  d_loss:0.4058  g_loss:1.6436
# epoch:615  d_loss:0.2552  g_loss:2.2775
# epoch:616  d_loss:0.4198  g_loss:1.8590
# epoch:617  d_loss:0.4682  g_loss:2.1982
# epoch:618  d_loss:0.3025  g_loss:2.0039
# epoch:619  d_loss:0.4138  g_loss:2.4854
# epoch:620  d_loss:0.3457  g_loss:2.9220
# epoch:621  d_loss:0.3845  g_loss:2.8110
# epoch:622  d_loss:0.3827  g_loss:2.2400
# epoch:623  d_loss:0.2643  g_loss:2.1505
# epoch:624  d_loss:0.2478  g_loss:2.2995
# epoch:625  d_loss:0.1900  g_loss:2.4065
# epoch:626  d_loss:0.2570  g_loss:2.3279
# epoch:627  d_loss:0.1221  g_loss:2.6601
# epoch:628  d_loss:0.2043  g_loss:2.3573
# epoch:629  d_loss:0.1710  g_loss:2.9441
# epoch:630  d_loss:0.3754  g_loss:2.2302
# epoch:631  d_loss:0.2022  g_loss:2.0069
# epoch:632  d_loss:0.2681  g_loss:1.8453
# epoch:633  d_loss:0.2674  g_loss:1.9525
# epoch:634  d_loss:0.2963  g_loss:2.1254
# epoch:635  d_loss:0.2348  g_loss:2.1454
# epoch:636  d_loss:0.2718  g_loss:2.3387
# epoch:637  d_loss:0.2837  g_loss:2.7095
# epoch:638  d_loss:0.4239  g_loss:2.1141
# epoch:639  d_loss:0.3437  g_loss:2.1574
# epoch:640  d_loss:0.2495  g_loss:1.7694
# epoch:641  d_loss:0.4783  g_loss:1.7319
# epoch:642  d_loss:0.3775  g_loss:2.1783
# epoch:643  d_loss:0.3837  g_loss:2.4258
# epoch:644  d_loss:0.5275  g_loss:2.8264
# epoch:645  d_loss:0.8068  g_loss:2.3040
# epoch:646  d_loss:0.5800  g_loss:1.6206
# epoch:647  d_loss:0.4969  g_loss:2.8000
# epoch:648  d_loss:0.4707  g_loss:3.9704
# epoch:649  d_loss:0.5342  g_loss:4.2695
# epoch:650  d_loss:0.7457  g_loss:2.6730
# epoch:651  d_loss:0.8650  g_loss:2.3734
# epoch:652  d_loss:0.4367  g_loss:2.9038
# epoch:653  d_loss:0.7719  g_loss:2.6427
# epoch:654  d_loss:0.5831  g_loss:2.2270
# epoch:655  d_loss:0.8000  g_loss:2.2033
# epoch:656  d_loss:0.4495  g_loss:2.3129
# epoch:657  d_loss:0.4883  g_loss:2.9392
# epoch:658  d_loss:0.4916  g_loss:2.4712
# epoch:659  d_loss:0.4360  g_loss:2.7727
# epoch:660  d_loss:0.3264  g_loss:1.8815
# epoch:661  d_loss:0.5425  g_loss:1.4689
# epoch:662  d_loss:0.3683  g_loss:1.5477
# epoch:663  d_loss:0.3121  g_loss:1.8300
# epoch:664  d_loss:0.2754  g_loss:2.1338
# epoch:665  d_loss:0.3464  g_loss:2.4066
# epoch:666  d_loss:0.1675  g_loss:2.6270
# epoch:667  d_loss:0.2220  g_loss:2.5756
# epoch:668  d_loss:0.1956  g_loss:2.6896
# epoch:669  d_loss:0.2821  g_loss:2.5714
# epoch:670  d_loss:0.2430  g_loss:2.2671
# epoch:671  d_loss:0.2397  g_loss:1.9960
# epoch:672  d_loss:0.4571  g_loss:1.3934
# epoch:673  d_loss:0.2853  g_loss:1.9822
# epoch:674  d_loss:0.4045  g_loss:2.0816
# epoch:675  d_loss:0.3520  g_loss:2.3481
# epoch:676  d_loss:0.4387  g_loss:1.7969
# epoch:677  d_loss:0.5049  g_loss:1.6602
# epoch:678  d_loss:0.4866  g_loss:1.7838
# epoch:679  d_loss:0.6612  g_loss:2.1105
# epoch:680  d_loss:0.6668  g_loss:2.2571
# epoch:681  d_loss:0.5189  g_loss:2.0044
# epoch:682  d_loss:0.6848  g_loss:2.0283
# epoch:683  d_loss:0.6605  g_loss:1.8335
# epoch:684  d_loss:0.5107  g_loss:2.0531
# epoch:685  d_loss:0.9094  g_loss:2.1326
# epoch:686  d_loss:0.8298  g_loss:1.7512
# epoch:687  d_loss:0.7689  g_loss:1.4300
# epoch:688  d_loss:0.8749  g_loss:1.3144
# epoch:689  d_loss:0.5619  g_loss:1.3371
# epoch:690  d_loss:0.6170  g_loss:1.3746
# epoch:691  d_loss:0.6267  g_loss:1.0463
# epoch:692  d_loss:0.6935  g_loss:1.1983
# epoch:693  d_loss:0.4968  g_loss:1.3504
# epoch:694  d_loss:0.4505  g_loss:1.4314
# epoch:695  d_loss:0.3554  g_loss:1.9788
# epoch:696  d_loss:0.2945  g_loss:2.2064
# epoch:697  d_loss:0.2693  g_loss:2.1039
# epoch:698  d_loss:0.3025  g_loss:2.5713
# epoch:699  d_loss:0.2981  g_loss:2.4093
# epoch:700  d_loss:0.2302  g_loss:2.7310
# epoch:701  d_loss:0.3357  g_loss:2.4821
# epoch:702  d_loss:0.2766  g_loss:2.0303
# epoch:703  d_loss:0.3901  g_loss:2.2390
# epoch:704  d_loss:0.3999  g_loss:2.1149
# epoch:705  d_loss:0.3516  g_loss:2.1939
# epoch:706  d_loss:0.5981  g_loss:2.4311
# epoch:707  d_loss:0.2962  g_loss:2.2950
# epoch:708  d_loss:0.6356  g_loss:2.0468
# epoch:709  d_loss:0.5751  g_loss:1.4634
# epoch:710  d_loss:0.6006  g_loss:1.0451
# epoch:711  d_loss:0.5994  g_loss:0.8979
# epoch:712  d_loss:0.5897  g_loss:1.3098
# epoch:713  d_loss:0.5446  g_loss:1.2116
# epoch:714  d_loss:0.7108  g_loss:1.4748
# epoch:715  d_loss:0.6941  g_loss:1.2776
# epoch:716  d_loss:0.5487  g_loss:1.7395
# epoch:717  d_loss:0.8691  g_loss:1.6426
# epoch:718  d_loss:0.3606  g_loss:1.2888
# epoch:719  d_loss:0.5623  g_loss:1.6788
# epoch:720  d_loss:0.4064  g_loss:1.8211
# epoch:721  d_loss:0.3795  g_loss:2.4046
# epoch:722  d_loss:0.3542  g_loss:2.9715
# epoch:723  d_loss:0.2626  g_loss:2.5864
# epoch:724  d_loss:0.3836  g_loss:2.2327
# epoch:725  d_loss:0.4200  g_loss:2.4650
# epoch:726  d_loss:0.2638  g_loss:2.2104
# epoch:727  d_loss:0.4158  g_loss:1.9618
# epoch:728  d_loss:0.3671  g_loss:2.1505
# epoch:729  d_loss:0.2538  g_loss:2.3806
# epoch:730  d_loss:0.5389  g_loss:2.4624
# epoch:731  d_loss:0.2651  g_loss:2.7986
# epoch:732  d_loss:0.3934  g_loss:2.6289
# epoch:733  d_loss:0.3536  g_loss:2.8902
# epoch:734  d_loss:0.3237  g_loss:2.9452
# epoch:735  d_loss:0.3297  g_loss:2.7989
# epoch:736  d_loss:0.3893  g_loss:2.3595
# epoch:737  d_loss:0.3691  g_loss:2.1931
# epoch:738  d_loss:0.3812  g_loss:2.3077
# epoch:739  d_loss:0.4054  g_loss:2.1818
# epoch:740  d_loss:0.4288  g_loss:2.1833
# epoch:741  d_loss:0.3979  g_loss:2.1638
# epoch:742  d_loss:0.4634  g_loss:2.0878
# epoch:743  d_loss:0.3879  g_loss:1.7537
# epoch:744  d_loss:0.3405  g_loss:2.1171
# epoch:745  d_loss:0.2209  g_loss:2.8954
# epoch:746  d_loss:0.4292  g_loss:2.7363
# epoch:747  d_loss:0.2424  g_loss:2.4717
# epoch:748  d_loss:0.2504  g_loss:1.9110
# epoch:749  d_loss:0.3575  g_loss:1.8491
# epoch:750  d_loss:0.2930  g_loss:2.1345
# epoch:751  d_loss:0.3130  g_loss:2.7058
# epoch:752  d_loss:0.2352  g_loss:3.0960
# epoch:753  d_loss:0.2830  g_loss:2.7602
# epoch:754  d_loss:0.4043  g_loss:1.8759
# epoch:755  d_loss:0.3172  g_loss:1.9712
# epoch:756  d_loss:0.4462  g_loss:2.0277
# epoch:757  d_loss:0.3817  g_loss:1.9817
# epoch:758  d_loss:0.5904  g_loss:1.7113
# epoch:759  d_loss:0.4021  g_loss:2.0206
# epoch:760  d_loss:0.5909  g_loss:1.7190
# epoch:761  d_loss:0.3470  g_loss:1.3783
# epoch:762  d_loss:0.6032  g_loss:1.3156
# epoch:763  d_loss:0.6417  g_loss:1.5538
# epoch:764  d_loss:0.6519  g_loss:2.0868
# epoch:765  d_loss:0.7658  g_loss:1.6905
# epoch:766  d_loss:0.7646  g_loss:1.3511
# epoch:767  d_loss:0.5675  g_loss:1.1802
# epoch:768  d_loss:0.6430  g_loss:1.1892
# epoch:769  d_loss:0.6521  g_loss:1.7308
# epoch:770  d_loss:0.6035  g_loss:1.9112
# epoch:771  d_loss:0.6245  g_loss:1.6658
# epoch:772  d_loss:0.5514  g_loss:1.5681
# epoch:773  d_loss:0.4344  g_loss:1.7244
# epoch:774  d_loss:0.2838  g_loss:2.2584
# epoch:775  d_loss:0.3746  g_loss:2.3176
# epoch:776  d_loss:0.3873  g_loss:2.1400
# epoch:777  d_loss:0.2736  g_loss:2.1558
# epoch:778  d_loss:0.1761  g_loss:2.5627
# epoch:779  d_loss:0.1854  g_loss:2.8216
# epoch:780  d_loss:0.2160  g_loss:2.9727
# epoch:781  d_loss:0.2377  g_loss:3.3067
# epoch:782  d_loss:0.2374  g_loss:2.7859
